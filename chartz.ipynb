# %% [markdown]
# #                                             Chartz Scraper

# %% [markdown]
# ## Présentation du projet

# %% [markdown]
# Projet de scraping sur les certifications de la SNEP pour ressortir des données non proposées sur le site.

# %% [markdown]
# ### Création du scraper

# %% [markdown]
# Installation de scrapy:

# %%
# !pip install scrapy

# %% [markdown]
# ### Code source du scraper:

# %%
# %load chartzscraper.py

import scrapy

class ChartzScraper(scrapy.Spider):
    name = 'snep'
    lien = 'https://snepmusique.com/les-certifications/page/'
    for i in range(100):
        lienConcat = lien+str(i)
        start_urls = [lienConcat]

        def parse(self, response):
            for certifications in response.css('div.certification'):
                yield {
                    'artiste': certifications.css('div.artiste::text').get(),
                    'titre': certifications.css('div.titre::text').get(),
                    'categorie': certifications.css('div.categorie::text').get(),
                    'editeur': certifications.css('div.editeur::text').get(),
                    'certification': certifications.css('div.certif::text').get(),
                }

# %%
# !scrapy runspider chartzscraper.py
# Out:
# 2021-04-29 00:21:05 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2021-04-29 00:21:05 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Windows-10-10.0.19041-SP0
# 2021-04-29 00:21:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-04-29 00:21:05 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2021-04-29 00:21:05 [scrapy.extensions.telnet] INFO: Telnet Password: e9849665fce05942
# 2021-04-29 00:21:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-04-29 00:21:06 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...

# %%
# !pip install pymongo

# %%
import pandas as pd
import pymongo 
import json

# %%
client = pymongo.MongoClient("mongodb://Chartz:12345@cluster0-shard-00-00.nhbtv.mongodb.net:27017,cluster0-shard-00-01.nhbtv.mongodb.net:27017,cluster0-shard-00-02.nhbtv.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-mpp71q-shard-0&authSource=admin&retryWrites=true&w=majority")
database = client['Chartz']
collection = database['snep']

# %%
df = pd.read_json("snep.json")
df.head(10)
# Out:
#                  artiste                                            titre  \
# 0        IMAGINE DRAGONS                                          NATURAL
# 1                  DAMSO                                       BALTRINGUE
# 2                    PLK                                            POLAK
# 3  TROIS CAFÉS GOURMANDS                                   UN AIR DE RIEN
# 4                   RÉMY                                       C'EST RÉMY
# 5    ORELSAN FEAT. DAMSO                                   RÊVES BIZARRES
# 6                  NISKA                                         SILICONÉ
# 7           KENDJI GIRAC                                         ENSEMBLE
# 8              LIL NAS X                                    OLD TOWN ROAD
# 9   JEAN-JACQUES GOLDMAN  SOUVENIRS DE TOURNÉE (CARNET DE ROUTE + TRACES)
#
#   categorie                                            editeur   certification
# ...

# %%
with open('snep.json') as json_data:
    tracks = json.load(json_data)
collection.insert_many(tracks)

# %%
#nombre de certifications différentes:
len(collection.distinct('certification'))
# Out:
# 8

# %%
#nombre de catégories différentes:
len(collection.distinct('categorie'))
# Out:
# 3

# %%
#tous les tracks de DAMSO dans la bdd
res = collection.find({"artiste": "DAMSO"})
list(res)
# Out:
# [{'_id': ObjectId('6089ca503a2e81130f601019'),
#   'artiste': 'DAMSO',
#   'titre': 'BALTRINGUE',
#   'categorie': 'Singles',
#   'editeur': 'Universal Music Division Capitol Music / UNIVERSAL MUSIC FRANCE',
#   'certification': 'Or'},
#  {'_id': ObjectId('6089ca503a2e81130f601046'),
#   'artiste': 'DAMSO',
#   'titre': 'DIX LEURRES',
#   'categorie': 'Singles',
#   'editeur': 'Universal Music Division Capitol Music F\t /  UNIVERSAL MUSIC FRANCE',
#   'certification': 'Or'},
#  {'_id': ObjectId('6089ca503a2e81130f601057'),
#   'artiste': 'DAMSO',
#   'titre': 'JULIEN',
#   'categorie': 'Singles',
#   'editeur': 'Universal Music Division Capitol Music F\t / UNIVERSAL MUSIC FRANCE',
#   'certification': 'Or'},
#  {'_id': ObjectId('6089ca503a2e81130f601068'),
#   'artiste': 'DAMSO',
#   'titre': '60 ANNÉES',
#   'categorie': 'Singles',
#   'editeur': 'Universal Music Division Capitol Music F\t / UNIVERSAL MUSIC FRANCE',
#   'certification': 'Or'},
# ...

# %%
#hits approuvés par El-Walid et Ibrahima
collection.update_one({"editeur":"DEF JAM / UNIVERSAL MUSIC"}, {"$set": {"approved_by":"El-Walid"}}, upsert =True)
collection.update_one({"editeur":"SONY MUSIC VIDEO / SONY MUSIC ENTERTAINMENT"}, {"$set": {"approved_by":"Ibrahima"}}, upsert =True)

# %%
res = collection.find({"editeur":"DEF JAM / UNIVERSAL MUSIC"})
next(res)
# Out:
# {'_id': ObjectId('6089ca503a2e81130f60101c'),
#  'artiste': 'RÉMY',
#  'titre': "C'EST RÉMY",
#  'categorie': 'Albums',
#  'editeur': 'DEF JAM / UNIVERSAL MUSIC',
#  'certification': 'Or',
#  'approved_by': 'El-Walid'}

# %%
res = collection.find({"editeur":"SONY MUSIC VIDEO / SONY MUSIC ENTERTAINMENT"})
next(res)
# Out:
# {'_id': ObjectId('6089ca503a2e81130f601021'),
#  'artiste': 'JEAN-JACQUES GOLDMAN',
#  'titre': 'SOUVENIRS DE TOURNÉE (CARNET DE ROUTE + TRACES)',
#  'categorie': 'Vidéos',
#  'editeur': 'SONY MUSIC VIDEO / SONY MUSIC ENTERTAINMENT',
#  'certification': 'Or',
#  'approved_by': 'Ibrahima'}

# %%
# !pip install plotly==4.14.3
# Out:
# ...
#      |████████████████████████████████| 13.2 MB 2.2 MB/s eta 0:00:01    |████████████▌                   | 5.1 MB 1.4 MB/s eta 0:00:06     |██████████████████              | 7.4 MB 649 kB/s eta 0:00:09     |████████████████████████▋       | 10.1 MB 2.3 MB/s eta 0:00:02     |████████████████████████████    | 11.5 MB 2.3 MB/s eta 0:00:01
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=2ebb135dd3ca9655c940a51dc12ab0d03d85a1a453b5005772687cadd10472f0
#   Stored in directory: /root/.cache/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artiste        990 non-null    object
#  1   titre          990 non-null    object
#  2   categorie      990 non-null    object
#  3   editeur        989 non-null    object
#  4   certification  990 non-null    object
# dtypes: object(5)
# memory usage: 38.8+ KB

# %%
dfLabel = df[df.certification == "Platine"]
dfLabel
# Out:
#                  artiste              titre categorie  \
# 0        IMAGINE DRAGONS            NATURAL   Singles
# 2                    PLK              POLAK    Albums
# 5    ORELSAN FEAT. DAMSO     RÊVES BIZARRES   Singles
# 6                  NISKA           SILICONÉ   Singles
# 15             COLUMBINE   ADIEU, AU REVOIR    Albums
# ..                   ...                ...       ...
# 978                  JUL    ELLE ET L'AUTRE   Singles
# 979    MULTI INTERPRÈTES         LA LA LAND    Albums
# 980          JULIEN DORÉ             LE LAC   Singles
# 984       ZAHO FEAT. MHD  LAISSEZ-LES KOUMA   Singles
# 987          MAÎTRE GIMS  TU VAS ME MANQUER   Singles
#
#                                                editeur certification
# 0          INTERSCOPE RECORDS / UNIVERSAL MUSIC FRANCE       Platine
# 2                                     PANENKA / WAGRAM       Platine
# 5                                 3EME BUREAU / WAGRAM       Platine
# ...

# %%
# data preparation
dfLabel = df[df.certification == "Platine"]
pie1 = df['certification'].value_counts()
labels = dfLabel.editeur
# figure
fig = {
  "data": [
    {
      "values": pie1,
      "labels": labels,
      "domain": {"x": [0, .5]},
      "name": "Nombre de certifcations Platines",
      "hoverinfo":"label",
      "hole": .3,
      "type": "pie"
    },],
  "layout": {
        "title":"Nombre de certifications Platine par editeur",
        "annotations": [
            { "font": { "size": 20},
              "showarrow": False,
              "text": "Proportion de disques de Platine",
                "x": 0.20,
                "y": 1
            },
        ]
    }
}
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-71-ceb97b0700b8> in <module>
#       4 labels = dfLabel.editeur
#       5 # figure
# ----> 6 import iplot
#       7 fig = {
#       8   "data": [
#
# ModuleNotFoundError: No module named 'iplot'

# %%
# prepare data frames
import plotly.graph_objs as go
dfLabel = df[df.certification == "Platine"]

# create trace1 
trace1 = go.Bar(
                x = dfLabel.editeur,
                name = "Certifications Platine",
                marker = dict(color = 'rgba(63, 72, 204)',
                             line=dict(color='rgb(0,0,0)',width=1.5)))
# create trace2 

data = [trace1]
layout = go.Layout(barmode = "group")
fig = go.Figure(data = data, layout = layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-c07b338acf29> in <module>
#      14 layout = go.Layout(barmode = "group")
#      15 fig = go.Figure(data = data, layout = layout)
# ---> 16 iplot(fig)
#
# NameError: name 'iplot' is not defined
